# %% [markdown]
# ## Libraries

# %%
import torch
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# ## Version control of Tor

# %%
#@title checking version of torch
print(torch.__version__)
print(torch.cuda.is_available())
print(torch.cuda.get_device_name(0))
# Out:
# 2.11.0+cu130
# True
# NVIDIA GeForce RTX 3050 6GB Laptop GPU

# %%
import os 
print(os.getcwd())
# Out:
# /home/julian/Documents/DL/stat_aware_pred/nbs

# %%
#@title off loading data
df=pd.read_csv("../data/well_log.csv")
